# %% [markdown]
# ## A simple demo of the cleaned data
# Please check the readme if you are interested in getting the data used in the analysis.

# %%
import pandas as pd
import numpy as np
from pprint import pprint

pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)
pd.set_option('max_colwidth', 50)

## Custom Package
import custom_script
from custom_script.data_cleaning import *

# %%
data_file = 'gameRecordsDataAnon_16-01-2021.json'
df = data_pipeline_df(data_file)
# Out:
# complete loading!
# ...
#
# rows and columns: (83013, 29)
# Complete filtering!
# Complete creating new features!
# Complete dropping!
# Complete data pipeline!
# ------------------------

# %%
df.head()
# Out:
#   spyTeam resistanceTeam playerUsernamesOrdered                                  roles                                     missionHistory  numFailsHistory                       _id  \
# 0  [a, e]      [b, c, d]        [a, b, c, d, e]  [Merlin, Percival, Assassin, Morgana]                  [succeeded, succeeded, succeeded]        [0, 0, 0]  600215429e23c300041f22c8
# 3  [b, d]      [a, c, e]        [a, b, c, d, e]  [Merlin, Percival, Assassin, Morgana]  [succeeded, failed, failed, succeeded, succeeded]  [0, 1, 1, 0, 0]  600213399e23c300041f22c4
# 5  [a, b]      [c, d, e]        [a, b, c, d, e]  [Merlin, Percival, Assassin, Morgana]  [succeeded, failed, failed, succeeded, succeeded]  [0, 1, 1, 0, 0]  60020f7c9e23c300041f22be
# 6  [c, d]      [a, b, e]        [a, b, c, d, e]  [Merlin, Percival, Assassin, Morgana]     [succeeded, failed, failed, succeeded, failed]  [0, 1, 1, 0, 1]  60020d4d9e23c300041f22ae
# ...

# %%
df.shape
# Out:
# (55040, 26)

# %%
df.iloc[0]
# Out:
# spyTeam                                                                [a, e]
# resistanceTeam                                                      [b, c, d]
# playerUsernamesOrdered                                        [a, b, c, d, e]
# roles                                   [Merlin, Percival, Assassin, Morgana]
# missionHistory                              [succeeded, succeeded, succeeded]
# numFailsHistory                                                     [0, 0, 0]
# _id                                                  600215429e23c300041f22c8
# timeGameStarted                                           2021-01-15 22:13:32
# timeAssassinationStarted                     2021-01-15 22:19:59.276000+00:00
# winningTeam                                                        Resistance
# numberOfPlayers                                                             5
# gameMode                                                               avalon
# ...
